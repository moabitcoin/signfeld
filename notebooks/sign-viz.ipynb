# %%
import os
import sys
import random
from PIL import Image
from pathlib import Path
from IPython.display import display

# %%
gtsd_data_dir = '/nas/team-space/experiments/turn_restrictions/synthetic-signs/dataset-14-08-2019/imgs'

# %%
image_dir = Path(gtsd_data_dir)

# %%
images = [x.resolve().as_posix() for x in image_dir.glob('*.jpg')]

# %%
len(images)
# Out:
# 100000

# %%
def show_random_image(images):
    
    img = random.sample(images, 1)[0]
    
    display(Image.open(img))

# %%
show_random_image(images)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=768x1024 at 0x7F86B367F080>
